# %% [markdown]
# # Evaluation
#
#
#
# Take a look at Timeseries anomaly detection using an Autoencoder at:
# https://keras.io/examples/timeseries/timeseries_anomaly_detection/
#
# ***
#
# https://keras.io/examples/timeseries/timeseries_anomaly_detection/

# %%
# Numerical arrays.
import numpy as np

# Spreadsheet-like Data Frames.
import pandas as pd

# Neural networks.
import tensorflow.keras as keras

# Plotting
import matplotlib.pyplot as plt

# %% [markdown]
# ## Data
#
# ***
#
# https://www.kaggle.com/datasets/boltzmannbrain/nab
#
# https://github.com/numenta/NAB

# %%
# Root of URLs.
root_url = 'https://raw.githubusercontent.com/numenta/NAB/master/data/'

# Data file without anomaly.
no_anomaly_url = root_url + 'artificialNoAnomaly/art_daily_small_noise.csv'

# Data file with anomaly.
with_anomaly_url = root_url + 'artificialWithAnomaly/art_daily_jumpsup.csv'

# %%
no_anomaly_url
# Out:
# 'https://raw.githubusercontent.com/numenta/NAB/master/data/artificialNoAnomaly/art_daily_small_noise.csv'

# %%
with_anomaly_url
# Out:
# 'https://raw.githubusercontent.com/numenta/NAB/master/data/artificialWithAnomaly/art_daily_jumpsup.csv'

# %%
# 
df_small_noise = pd.read_csv(no_anomaly_url, parse_dates=True, index_col="timestamp")

# %%
# 
df_small_noise.head()
# Out:
#                          value
# timestamp
# 2014-04-01 00:00:00  18.324919
# 2014-04-01 00:05:00  21.970327
# 2014-04-01 00:10:00  18.624806
# 2014-04-01 00:15:00  21.953684
# 2014-04-01 00:20:00  21.909120

# %%
# 
df_small_noise.describe()
# Out:
#              value
# count  4032.000000
# mean     42.438353
# std      28.077122
# min      18.000964
# 25%      19.841390
# 50%      21.608487
# 75%      75.450282
# max      87.976128

# %%
# 
df_small_noise.iloc[0]
# Out:
# value    18.324919
# Name: 2014-04-01 00:00:00, dtype: float64

# %%
# 
df_small_noise.iloc[0]['value']
# Out:
# 18.3249185392

# %%
# 
df_small_noise.iloc[0].values[0]
# Out:
# 18.3249185392

# %%
# 
df_small_noise.iloc[0].values[0] * 10e12
# Out:
# 183249185392000.0

# %%
# 
df_small_noise.shape
# Out:
# (4032, 1)

# %%
# 
fig, ax = plt.subplots(figsize=(10,4))

# Use pandas to plot data frame.
df_small_noise.plot(legend=False, ax=ax);

# %%
#
df_daily_jumpsup = pd.read_csv(with_anomaly_url, parse_dates=True, index_col="timestamp")

# %%
# 
df_daily_jumpsup.head()
# Out:
#                          value
# timestamp
# 2014-04-01 00:00:00  19.761252
# 2014-04-01 00:05:00  20.500833
# 2014-04-01 00:10:00  19.961641
# 2014-04-01 00:15:00  21.490266
# 2014-04-01 00:20:00  20.187739

# %%
# 
df_daily_jumpsup.describe()
# Out:
#              value
# count  4032.000000
# mean     44.494254
# std      32.432473
# min      18.001010
# 25%      19.991382
# 50%      21.648503
# 75%      76.435943
# max     164.947481

# %%
# 
df_daily_jumpsup.iloc[0]['value']
# Out:
# 19.761251903

# %%
# 
df_daily_jumpsup.shape
# Out:
# (4032, 1)

# %%
# 
fig, ax = plt.subplots(figsize=(10,4))

# Use pandas to plot data frame.
df_daily_jumpsup.plot(legend=False, ax=ax);

# %% [markdown]
# ## Preprocessing
#
# ***

# %%
# 
train_mean = df_small_noise.mean()

train_mean
# Out:
# value    42.438353
# dtype: float64

# %%
# 
train_std = df_small_noise.std()

train_std
# Out:
# value    28.077122
# dtype: float64

# %%
# 
df_train_vals = (df_small_noise - train_mean) / train_std

# %%
# 
df_train_vals.head()
# Out:
#                         value
# timestamp
# 2014-04-01 00:00:00 -0.858829
# 2014-04-01 00:05:00 -0.728993
# 2014-04-01 00:10:00 -0.848148
# 2014-04-01 00:15:00 -0.729586
# 2014-04-01 00:20:00 -0.731173

# %%
# 
df_small_noise['less_mean'] = df_small_noise['value'] - df_small_noise['value'].mean()
df_small_noise['div_std'] = df_small_noise['less_mean'] / df_small_noise['value'].std()

# %%
df_small_noise
# Out:
#                          value  less_mean   div_std
# timestamp
# 2014-04-01 00:00:00  18.324919 -24.113435 -0.858829
# 2014-04-01 00:05:00  21.970327 -20.468026 -0.728993
# 2014-04-01 00:10:00  18.624806 -23.813547 -0.848148
# 2014-04-01 00:15:00  21.953684 -20.484669 -0.729586
# 2014-04-01 00:20:00  21.909120 -20.529234 -0.731173
# ...                        ...        ...       ...
# 2014-04-14 23:35:00  20.211195 -22.227159 -0.791647
# 2014-04-14 23:40:00  20.531041 -21.907313 -0.780255
# 2014-04-14 23:45:00  19.032127 -23.406226 -0.833640
# 2014-04-14 23:50:00  21.798801 -20.639552 -0.735102
# 2014-04-14 23:55:00  18.682620 -23.755733 -0.846089
#
# [4032 rows x 3 columns]

# %%
df_small_noise['value'].mean(), df_small_noise['less_mean'].mean(), df_small_noise['div_std'].mean()
# Out:
# (42.438353335806646, -7.342627387941552e-14, -2.616541242931684e-15)

# %%
df_small_noise['value'].std(), df_small_noise['less_mean'].std(), df_small_noise['div_std'].std()
# Out:
# (28.077122281262515, 28.077122281262508, 1.0000000000000018)

# %%
# 
fig, ax = plt.subplots(figsize=(10,4))

# Use pandas to plot data frame.
df_train_vals.plot(legend=False, ax=ax);

# %%
# 
df_train_vals.shape
# Out:
# (4032, 1)

# %%
# 
window_size = 288

# %% [markdown]
# Window example:
#
# ```python
# [1, 1, 2, 4, 5, 6, 7, 1, 2, 3, 4, 5]
# window_size = 3
# [1, 1, 2]
# [1, 2, 4]
# [2, 4, 5]
# [4, 5, 6]
# ...
# ```

# %%
# Window list example.
L = [1, 1, 2, 4, 5, 6, 7, 1, 2, 3, 4, 5]
# Example window size.
win_size = 3
# Length of L.
len(L)
# Out:
# 12

# %%
# Number of windows from L.
len(L) - (win_size - 1)
# Out:
# 10

# %%
# Remove brackets.
len(L) - win_size + 1
# Out:
# 10

# %%
# Print the windows.
for i in range(len(L) - win_size + 1):
    print(L[i:i + win_size])
# Out:
# [1, 1, 2]
# [1, 2, 4]
# [2, 4, 5]
# [4, 5, 6]
# [5, 6, 7]
# [6, 7, 1]
# [7, 1, 2]
# [1, 2, 3]
# [2, 3, 4]
# [3, 4, 5]

# %%
# For accumulating the windows.
wins = []

# Generate the windows
for i in range(len(L) - win_size + 1):
    wins.append(L[i:i + win_size])

wins
# Out:
# [[1, 1, 2],
#  [1, 2, 4],
#  [2, 4, 5],
#  [4, 5, 6],
#  [5, 6, 7],
#  [6, 7, 1],
#  [7, 1, 2],
#  [1, 2, 3],
#  [2, 3, 4],
#  [3, 4, 5]]

# %%
# Create a 2D numpy array from wins.
np.stack(wins)
# Out:
# array([[1, 1, 2],
#        [1, 2, 4],
#        [2, 4, 5],
#        [4, 5, 6],
#        [5, 6, 7],
#        [6, 7, 1],
#        [7, 1, 2],
#        [1, 2, 3],
#        [2, 3, 4],
#        [3, 4, 5]])

# %%
# 
def windows(vals, N=window_size):
  # 
  L = []
  # 
  for i in range(len(vals) - N + 1):
    # 
    L.append(vals[i:i+N])
  # Stack
  return np.stack(L)

# %%
# 
x_train = windows(df_train_vals)

# %%
# 
x_train[0][0], x_train[-1][-1]
# Out:
# (array([-0.85882857]), array([-0.8460886]))

# %%
# 
df_train_vals.iloc[0], df_train_vals.iloc[-1]
# Out:
# (value   -0.858829
#  Name: 2014-04-01 00:00:00, dtype: float64,
#  value   -0.846089
#  Name: 2014-04-14 23:55:00, dtype: float64)

# %%
# 
x_train.shape
# Out:
# (3745, 288, 1)

# %%
#
df_train_vals['value'].values
# Out:
# array([-0.85882857, -0.72899302, -0.84814772, ..., -0.83364049,
#        -0.73510213, -0.8460886 ])

# %%
# 
x_train[0].flatten()
# Out:
# array([-0.85882857, -0.72899302, -0.84814772, -0.72958579, -0.731173  ,
#        -0.75730984, -0.77645641, -0.7880838 , -0.747012  , -0.829166  ,
#        -0.80377285, -0.7821597 , -0.81182078, -0.80949918, -0.82334701,
#        -0.79001779, -0.74922405, -0.84169024, -0.73727717, -0.77223023,
#        -0.75311352, -0.79116337, -0.75934728, -0.86809294, -0.75381057,
#        -0.86468256, -0.74361965, -0.72908121, -0.82850668, -0.84043795,
#        -0.76136364, -0.8343536 , -0.74708881, -0.85574949, -0.85245676,
#        -0.73090636, -0.77440264, -0.74974936, -0.82419543, -0.77402585,
#        -0.78574242, -0.7844733 , -0.77316412, -0.78843253, -0.80927467,
#        -0.83109167, -0.76090519, -0.83816509, -0.77176485, -0.83715923,
#        -0.78131343, -0.76396862, -0.83924191, -0.86186112, -0.85174179,
#        -0.78406773, -0.74938477, -0.86399047, -0.76581026, -0.82177506,
#        -0.80222751, -0.73807119, -0.82310669, -0.80410682, -0.86845167,
#        -0.85877599, -0.83356075, -0.86643297, -0.78045221, -0.8096542 ,
#        -0.79230956, -0.84551986, -0.82824105, -0.77582935, -0.73287933,
#        -0.86321832, -0.74355256, -0.7882157 , -0.79006227, -0.79912888,
#        -0.86051472, -0.85759665, -0.78479216, -0.82182635, -0.73972257,
#        -0.81247611, -0.84998837, -0.76857869, -0.82860841, -0.79553994,
#        -0.77098436, -0.74214503, -0.75754161, -0.77404332, -0.77357716,
#        -0.73564002, -0.82825643, -0.8702425 , -0.83165699, -0.83935909,
#        -0.77611284, -0.78011937, -0.78585361, -0.86808681, -0.76657575,
#        -0.82430925, -0.7756539 , -0.79110813,  0.83423034,  0.73340436,
#         0.71395293,  1.07098925,  1.11307181,  0.98296271,  0.71831972,
#         0.86295228,  1.02130195,  1.04594803,  0.72548104,  0.66823317,
#         1.36958529,  1.17305538,  1.11661005,  0.98307138,  1.27459976,
#         1.44642694,  1.50528567,  1.28866513,  1.26031743,  1.02295817,
#         1.27933882,  1.18598059,  1.3813925 ,  1.25767699,  1.1736019 ,
#         1.09127902,  1.21586925,  1.09223039,  1.13768838,  1.59675342,
#         1.28904484,  1.33876025,  1.53233922,  1.60141677,  1.38146244,
#         1.51223576,  1.23588256,  1.22381772,  1.2790048 ,  1.43257027,
#         1.43808241,  1.22922231,  1.12561563,  1.40974009,  1.12283575,
#         1.37905941,  1.44731563,  1.45141157,  1.48152744,  1.54954504,
#         1.33709539,  1.46829683,  1.4050141 ,  1.15859057,  1.06689361,
#         1.21436719,  1.30466379,  1.40383661,  1.53708371,  1.16457702,
#         1.12429225,  1.60177134,  1.11431721,  1.32540935,  1.38642273,
#         1.36124227,  1.10177385,  1.08524575,  1.1128578 ,  1.38643638,
#         1.36304532,  1.18604649,  1.41628631,  1.52016681,  1.07654239,
#         1.33670957,  1.44565443,  1.19662931,  1.22823281,  1.40253218,
#         1.56454005,  1.51438674,  1.38516952,  1.46899077,  1.26076513,
#         1.41812743,  1.31852542,  1.16110478,  1.45275926,  1.36997393,
#         1.25723151,  1.57220199,  1.06479764,  1.23281399,  1.08528647,
#         1.48968441,  1.45297419,  1.24169607,  1.43790453,  1.2785004 ,
#         1.48382995,  1.31169265,  1.28781332,  1.58553613,  1.19583776,
#         1.12151008, -0.35250349, -0.26479567, -0.39962031, -0.47160544,
#        -0.40840388, -0.37042247, -0.44883702, -0.33573617, -0.25831579,
#        -0.38277522, -0.40488824, -0.39440839, -0.77509723, -0.65253443,
#        -0.72728022, -0.73167631, -0.6882095 , -0.72293893, -0.69003755,
#        -0.78366561, -0.6636319 , -0.64340272, -0.68995268, -0.64115899,
#        -0.83292321, -0.78536741, -0.76722084, -0.77014874, -0.79644794,
#        -0.80569367, -0.83651316, -0.79786583, -0.83128515, -0.74788262,
#        -0.82454968, -0.84647101, -0.78825327, -0.78211741, -0.74251058,
#        -0.7847296 , -0.8178686 , -0.75237369, -0.78998354, -0.85597483,
#        -0.78632299, -0.73734213, -0.81059211, -0.82490508, -0.84932652,
#        -0.84818912, -0.80807162, -0.78484064, -0.8582896 , -0.73580158,
#        -0.76210229, -0.78613203, -0.75164888, -0.85835073, -0.80178754,
#        -0.77993325, -0.75220135, -0.75863962, -0.83079766, -0.73620985,
#        -0.85255954, -0.74557822, -0.73192653, -0.84503486, -0.76738913,
#        -0.86453747, -0.81250829, -0.79671155])

# %%
# 
window_no = 200

# 
fig, ax = plt.subplots(figsize=(12, 6))

# 
y = df_train_vals['value'].values

# 
ax.plot(np.arange(y.shape[0]), y, label='signal')

# The first window.
w = x_train[window_no].flatten()

# 
ax.plot(np.arange(w.shape[0]) + window_no, w, label='window')

ax.legend();

# %% [markdown]
# ## Neural Network
#
# ***

# %%
x_train.shape
# Out:
# (3745, 288, 1)

# %%
#
layers = [
  #
  keras.layers.Input(shape=(x_train.shape[1], x_train.shape[2])),
  #
  keras.layers.Conv1D(
    filters=32, kernel_size=7, padding="same", strides=2, activation="relu"),
  #
  keras.layers.Dropout(rate=0.2),
  #
  keras.layers.Conv1D(
    filters=16, kernel_size=7, padding="same", strides=2, activation="relu"),
  #
  keras.layers.Conv1DTranspose(
    filters=16, kernel_size=7, padding="same", strides=2, activation="relu"),
  #
  keras.layers.Dropout(rate=0.2),
  #
  keras.layers.Conv1DTranspose(
    filters=32, kernel_size=7, padding="same", strides=2, activation="relu"),
  #
  keras.layers.Conv1DTranspose(filters=1, kernel_size=7, padding="same"),
]

# %%
#
model = keras.Sequential(layers)

# %%
# 
optimizer = keras.optimizers.Adam(learning_rate=0.001)

# %%
# 
model.compile(optimizer=optimizer, loss="mse")

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 144, 32)           256
#
#  dropout (Dropout)           (None, 144, 32)           0
#
#  conv1d_1 (Conv1D)           (None, 72, 16)            3600
#
#  conv1d_transpose (Conv1DTra  (None, 144, 16)          1808
#  nspose)
#
#  dropout_1 (Dropout)         (None, 144, 16)           0
#
#  conv1d_transpose_1 (Conv1DT  (None, 288, 32)          3616
#  ranspose)
#
#  conv1d_transpose_2 (Conv1DT  (None, 288, 1)           225
#  ranspose)
#
# =================================================================
# Total params: 9,505
# Trainable params: 9,505
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 
history = model.fit(
    x_train,
    x_train,
    epochs=50,
    batch_size=128,
    validation_split=0.1,
    callbacks=[
        keras.callbacks.EarlyStopping(monitor="val_loss", patience=5, mode="min")
    ],
)
# Out:
# Epoch 1/50
# 27/27 [==============================] - 3s 73ms/step - loss: 0.6614 - val_loss: 0.0849
# Epoch 2/50
# 27/27 [==============================] - 2s 60ms/step - loss: 0.0952 - val_loss: 0.0456
# Epoch 3/50
# 27/27 [==============================] - 2s 71ms/step - loss: 0.0597 - val_loss: 0.0358
# Epoch 4/50
# 27/27 [==============================] - 1s 55ms/step - loss: 0.0500 - val_loss: 0.0308
# Epoch 5/50
# 27/27 [==============================] - 2s 57ms/step - loss: 0.0441 - val_loss: 0.0280
# Epoch 6/50
# 27/27 [==============================] - 1s 56ms/step - loss: 0.0401 - val_loss: 0.0261
# Epoch 7/50
# 27/27 [==============================] - 2s 60ms/step - loss: 0.0369 - val_loss: 0.0245
# Epoch 8/50
# 27/27 [==============================] - 2s 62ms/step - loss: 0.0337 - val_loss: 0.0225
# Epoch 9/50
# 27/27 [==============================] - 2s 74ms/step - loss: 0.0311 - val_loss: 0.0214
# Epoch 10/50
# 27/27 [==============================] - 2s 60ms/step - loss: 0.0289 - val_loss: 0.0195
# Epoch 11/50
# 27/27 [==============================] - 2s 69ms/step - loss: 0.0273 - val_loss: 0.0188
# Epoch 12/50
# 27/27 [==============================] - 2s 92ms/step - loss: 0.0256 - val_loss: 0.0179
# Epoch 13/50
# 27/27 [==============================] - 2s 91ms/step - loss: 0.0245 - val_loss: 0.0175
# Epoch 14/50
# 27/27 [==============================] - 2s 66ms/step - loss: 0.0235 - val_loss: 0.0176
# Epoch 15/50
# 27/27 [==============================] - 2s 57ms/step - loss: 0.0227 - val_loss: 0.0162
# Epoch 16/50
# 27/27 [==============================] - 2s 81ms/step - loss: 0.0220 - val_loss: 0.0169
# Epoch 17/50
# 27/27 [==============================] - 2s 70ms/step - loss: 0.0213 - val_loss: 0.0167
# Epoch 18/50
# 27/27 [==============================] - 2s 74ms/step - loss: 0.0207 - val_loss: 0.0174
# Epoch 19/50
# 27/27 [==============================] - 2s 65ms/step - loss: 0.0201 - val_loss: 0.0170
# Epoch 20/50
# 27/27 [==============================] - 2s 81ms/step - loss: 0.0196 - val_loss: 0.0165

# %% [markdown]
# ## Evaluation
#
# ***

# %%
history.history["loss"]
# Out:
# [0.6613775491714478,
#  0.09518677741289139,
#  0.059717807918787,
#  0.04996270313858986,
#  0.0441322848200798,
#  0.040054429322481155,
#  0.03687157854437828,
#  0.03371153771877289,
#  0.031131869181990623,
#  0.028917230665683746,
#  0.027276642620563507,
#  0.025623328983783722,
#  0.024532122537493706,
#  0.023511944338679314,
#  0.022726023569703102,
#  0.021983914077281952,
#  0.02129938453435898,
#  0.020670194178819656,
#  0.020149163901805878,
#  0.019648971036076546]

# %%
history.history["val_loss"]
# Out:
# [0.08493289351463318,
#  0.045564960688352585,
#  0.035839732736349106,
#  0.030801961198449135,
#  0.027963541448116302,
#  0.026084456592798233,
#  0.02445247210562229,
#  0.02250581607222557,
#  0.021374380216002464,
#  0.019478987902402878,
#  0.018756845965981483,
#  0.01788007840514183,
#  0.01749892719089985,
#  0.017581433057785034,
#  0.01616755872964859,
#  0.016869202256202698,
#  0.016736352816224098,
#  0.01738506741821766,
#  0.017029142007231712,
#  0.01650328002870083]

# %%
# 
fig, ax = plt.subplots(figsize=(10, 6))
# 
ax.plot(history.history["loss"], label="Training Loss")
# 
ax.plot(history.history["val_loss"], label="Validation Loss")
# 
ax.legend();

# %%
# Get train MAE loss.
x_train_pred = model.predict(x_train)
# Out:
# 118/118 [==============================] - 1s 6ms/step

# %%
# Calculate loss...
train_mae_loss = np.mean(np.abs(x_train_pred - x_train), axis=1)

# %%
# 
fig, ax = plt.subplots(figsize=(10, 6))
# 
ax.hist(train_mae_loss, bins=50)
# 
ax.set_xlabel("Train MAE loss")
#
ax.set_ylabel("No of samples");

# %%
# Get reconstruction loss threshold.
threshold = np.max(train_mae_loss)

# 
threshold
# Out:
# 0.11726894767262373

# %%
# 
fig, ax = plt.subplots(figsize=(10, 6))

# 
ax.plot(x_train[0])

# 
ax.plot(x_train_pred[0]);

# %%
# 
df_test_value = (df_daily_jumpsup - train_mean) / train_std

# %%
# 
fig, ax = plt.subplots(figsize=(10, 6))

# 
df_test_value.plot(legend=False, ax=ax);

# %%
# Create sequences from test values.
x_test = windows(df_test_value.values)

x_test.shape
# Out:
# (3745, 288, 1)

# %%
# 
x_test_pred = model.predict(x_test)
# Out:
# 118/118 [==============================] - 1s 6ms/step

# %%
# 
test_mae_loss = np.mean(np.abs(x_test_pred - x_test), axis=1)

test_mae_loss
# Out:
# array([[0.09839202],
#        [0.09974222],
#        [0.10276452],
#        ...,
#        [0.09818361],
#        [0.10099786],
#        [0.100174  ]])

# %%
# 
test_mae_loss = test_mae_loss.reshape((-1))

test_mae_loss
# Out:
# array([0.09839202, 0.09974222, 0.10276452, ..., 0.09818361, 0.10099786,
#        0.100174  ])

# %%
# 
fig, ax = plt.subplots(figsize=(10, 6))

#
ax.hist(test_mae_loss, bins=50)

# 
ax.set_xlabel("test MAE loss")

# 
ax.set_ylabel("No of samples");

# %%
# Detect all the samples which are anomalies.
anomalies = test_mae_loss > threshold

# NUmber of anomalies.
np.sum(anomalies)
# Out:
# 404

# %%
# data i is an anomaly if samples [(i - timesteps + 1) to (i)] are anomalies
inds = []

for i in range(window_size - 1, len(df_test_value) - window_size + 1):
    if np.all(anomalies[i - window_size + 1 : i]):
        inds.append(i)

# %%
# 
df_subset = df_daily_jumpsup.iloc[inds]

# %%
#
fig, ax = plt.subplots(figsize=(10, 6))

# 
df_daily_jumpsup.plot(legend=False, ax=ax)

# 
df_subset.plot(legend=False, ax=ax, color="r");

# %% [markdown]
# ***
#
# ## End
